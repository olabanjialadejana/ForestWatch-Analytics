# %%
from app.modules.analysis import get_forest_col, get_forest_loss, calculate_total_loss_per_year, plot_forest_loss_histogram, plot_forest_loss_map

# %%
# 1. Get processed forest loss data
forest_collection = get_forest_col('C:\Python Training\ForestWatch-Analytics\yankari.geojson')
forest_loss_raster = get_forest_loss('C:\Python Training\ForestWatch-Analytics\yankari.geojson')
final_table = calculate_total_loss_per_year(forest_loss_raster)
final_table
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# GEE initialized (existing token).
# Authenticated
# GEE initialized (existing token).
# Automatically determined UTM CRS: EPSG:32632
# GEE initialized (existing token).
# Automatically determined UTM CRS: EPSG:32632
# ...

# %%
plot_forest_loss_histogram(forest_loss_raster)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
aoi = 'C:\Python Training\ForestWatch-Analytics\yankari.geojson'
plot_forest_loss_map(forest_loss_raster, 2010, aoi)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ...
